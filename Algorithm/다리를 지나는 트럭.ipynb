# %% [markdown]
# ## 문제 설명
# - 트럭 여러 대가 강을 가로지르는 일차선 다리를 정해진 순으로 건너려 합니다. 모든 트럭이 다리를 건너려면 최소 몇 초가 걸리는지 알아내야 합니다. 다리에는 트럭이 최대 bridge_length대 올라갈 수 있으며, 다리는 weight 이하까지의 무게를 견딜 수 있습니다. 단, 다리에 완전히 오르지 않은 트럭의 무게는 무시합니다.
#
#
# - 예를 들어, 트럭 2대가 올라갈 수 있고 무게를 10kg까지 견디는 다리가 있습니다. 무게가 [7, 4, 5, 6]kg인 트럭이 순서대로 최단 시간 안에 다리를 건너려면 다음과 같이 건너야 합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 따라서, 모든 트럭이 다리를 지나려면 최소 8초가 걸립니다.
#
#
# - solution 함수의 매개변수로 다리에 올라갈 수 있는 트럭 수 bridge_length, 다리가 견딜 수 있는 무게 weight, 트럭 별 무게 truck_weights가 주어집니다. 이때 모든 트럭이 다리를 건너려면 최소 몇 초가 걸리는지 return 하도록 solution 함수를 완성하세요.

# %% [markdown]
# ![](https://s3.us-west-2.amazonaws.com/secure.notion-static.com/0c83cb03-ba9e-4572-a708-cff1689bef95/Untitled.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAT73L2G45O3KS52Y5%2F20210715%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20210715T002431Z&X-Amz-Expires=86400&X-Amz-Signature=6bd849c94a53a30b10cda72cbb096818c32478bb871a4d4be0a13cf43cf49a2f&X-Amz-SignedHeaders=host&response-content-disposition=filename%20%3D%22Untitled.png%22)

# %%
bridge_length = 2
weight = 10
truck_weights = [7,4,5,6]

# %%
bridge_length = 100
weight = 100
truck_weights = [10]

# %%
bridge_length = 2
weight = 10
truck_weights = [7,4,5,6]

from collections import deque

deq_complete = deque()
deq_ing = deque()
deq_wait = deque()

answer = 0

for _ in range(bridge_length):
    deq_ing.append(0)

for i in truck_weights:
    deq_wait.append(i)
    
while True: 
    
    if sum(deq_wait) > 0:
        
        x = deq_wait.popleft()
        deq_ing.append(x)
        
        answer += 1
        
        if sum(deq_ing) >= 0:
            
            y = deq_ing.popleft()
            deq_complete.append(y)
            
        else:
            
            break
        
        print('deq_wait', deq_wait)
        print('deq_ing', deq_ing)
        print('deq_complete', deq_complete)        
        print(11111)
        
    print('deq_wait', deq_wait)
    print('deq_ing', deq_ing)
    print('deq_complete', deq_complete)        
    print(11111)
        
print(answer)
# 추후 개선
# Out:
# deq_wait deque([4, 5, 6])
# deq_ing deque([0, 7])
# deq_complete deque([0])
# 11111
# deq_wait deque([4, 5, 6])
# deq_ing deque([0, 7])
# deq_complete deque([0])
# 11111
# deq_wait deque([5, 6])
# deq_ing deque([7, 4])
# deq_complete deque([0, 0])
# 11111
# deq_wait deque([5, 6])
# deq_ing deque([7, 4])
# deq_complete deque([0, 0])
# 11111
# deq_wait deque([6])
# deq_ing deque([4, 5])
# deq_complete deque([0, 0, 7])
# 11111
# deq_wait deque([6])
# deq_ing deque([4, 5])
# deq_complete deque([0, 0, 7])
# 11111
# deq_wait deque([])
# deq_ing deque([5, 6])
# deq_complete deque([0, 0, 7, 4])
# 11111
# deq_wait deque([])
# deq_ing deque([5, 6])
# deq_complete deque([0, 0, 7, 4])
# 11111
# deq_wait deque([])
# deq_ing deque([5, 6])
# deq_complete deque([0, 0, 7, 4])
# 11111
# deq_wait deque([])
# deq_ing deque([5, 6])
# deq_complete deque([0, 0, 7, 4])
# 11111
# deq_wait deque([])
# deq_ing deque([5, 6])
# deq_complete deque([0, 0, 7, 4])
# 11111
# deq_wait deque([])
# ...
