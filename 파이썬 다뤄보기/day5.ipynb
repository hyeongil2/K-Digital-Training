# %%
# -*- coding: utf-8 -*-

import wikipedia
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

wiki = wikipedia.page("Bangtan Boys")
text = wiki.content

wordcloud = WordCloud(width = 2000, height = 1500).generate(text)

plt.figure(figsize = (40, 30))

plt.imshow(wordcloud)
plt.show()

# 불용어 활용
s_word = STOPWORDS.union({'one','using','first','two','make','use'})
wordcloud2 = WordCloud(width = 2000, height = 1500,
                       stopwords = s_word,
                       background_color = 'white',
                       font_path = "font/HARLOWSI.TTF").generate(text)

plt.figure(figsize = (40, 30))

plt.imshow(wordcloud2)
plt.show()

# %%
# error 이거 해보기
import wikipediaapi
wiki = wikipediaapi.Wikipedia('ko')
p_wiki = wiki.page('방탄소년단')
print(p_wiki.text)
wordcloud = WordCloud(font_path='C:Windows/Fonts/malgunbd.ttf', backgound_color='white').generate(p_wiki.text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-70d0f5b5da6f> in <module>
# ----> 1 import wikipediaapi
#       2 wiki = wikipediaapi.Wikipedia('ko')
#       3 p_wiki = wiki.page('방탄소년단')
#       4 print(p_wiki.text)
#       5 wordcloud = WordCloud(font_path='C:Windows/Fonts/malgunbd.ttf', backgound_color='white').generate(p_wiki.text)
#
# ModuleNotFoundError: No module named 'wikipediaapi'

# %%
import wikipedia api
# Out:
#   File "<ipython-input-5-4c6a8b289be6>", line 1
#     import wikipedia api
#                      ^
# SyntaxError: invalid syntax
