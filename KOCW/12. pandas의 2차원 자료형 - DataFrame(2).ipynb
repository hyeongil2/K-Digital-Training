# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1, 2, '서울'], [2, 25, '대전']],
                 index = ['홍길동', '홍길순'],
                 columns = ['순서', '나이', '지역'])
df.index = ['사람1', '사람2']
df.columns = ['연번', '연령', '도시']
df = df.rename(index = {'사람1' : '홍길동'})
df = df.rename(columns = { '연번':'순서', '연령':'나이'})

# %%
df
# Out:
#      순서  나이  도시
# 홍길동   1   2  서울
# 사람2   2  25  대전

# %%
df.loc['사람 3'] = [3, 30, '부산']

# %%
df
# Out:
#       순서  나이  도시
# 홍길동    1   2  서울
# 사람2    2  25  대전
# 사람 3   3  30  부산

# %%
df.loc['사람 4'] = 0

# %%
df
# Out:
#       순서  나이  도시
# 홍길동    1   2  서울
# 사람2    2  25  대전
# 사람 3   3  30  부산
# 사람 4   0   0   0

# %%
df.loc['사람 1'] = df.loc['홍길동']

# %%
df
# Out:
#       순서  나이  도시
# 홍길동    1   2  서울
# 사람2    2  25  대전
# 사람 3   3  30  부산
# 사람 4   0   0   0
# 사람 1   1   2  서울

# %%
df['나이대'] = ['20대', '20대', '30대', '0대', '20대']

# %%
df
# Out:
#       순서  나이  도시  나이대
# 홍길동    1   2  서울  20대
# 사람2    2  25  대전  20대
# 사람 3   3  30  부산  30대
# 사람 4   0   0   0   0대
# 사람 1   1   2  서울  20대

# %%
df['직업'] = '학생'

# %%
df
# Out:
#       순서  나이  도시  나이대  직업
# 홍길동    1   2  서울  20대  학생
# 사람2    2  25  대전  20대  학생
# 사람 3   3  30  부산  30대  학생
# 사람 4   0   0   0   0대  학생
# 사람 1   1   2  서울  20대  학생

# %%
df.loc['사람 4', '순서'] = 4

# %%
df
# Out:
#       순서  나이  도시  나이대  직업
# 홍길동    1   2  서울  20대  학생
# 사람2    2  25  대전  20대  학생
# 사람 3   3  30  부산  30대  학생
# 사람 4   4   0   0   0대  학생
# 사람 1   1   2  서울  20대  학생

# %%
df.iloc[3, 1] = 10

# %%
df
# Out:
#       순서  나이  도시  나이대  직업
# 홍길동    1   2  서울  20대  학생
# 사람2    2  25  대전  20대  학생
# 사람 3   3  30  부산  30대  학생
# 사람 4   4  10   0   0대  학생
# 사람 1   1   2  서울  20대  학생

# %%
df.loc['사람 4', ['도시', '나이대']] = ['광주', '10대']

# %%
df
# Out:
#       순서  나이  도시  나이대  직업
# 홍길동    1   2  서울  20대  학생
# 사람2    2  25  대전  20대  학생
# 사람 3   3  30  부산  30대  학생
# 사람 4   4  10  광주  10대  학생
# 사람 1   1   2  서울  20대  학생

# %%
df.iloc[3, [1, 3]] = [40,'40대']

# %%
df
# Out:
#       순서  나이  도시  나이대  직업
# 홍길동    1   2  서울  20대  학생
# 사람2    2  25  대전  20대  학생
# 사람 3   3  30  부산  30대  학생
# 사람 4   4  40  광주  40대  학생
# 사람 1   1   2  서울  20대  학생

# %%
df = df.drop('사람 4', axis = 0) # 행단위

# %%
df
# Out:
#       순서  나이  도시  나이대  직업
# 홍길동    1   2  서울  20대  학생
# 사람2    2  25  대전  20대  학생
# 사람 3   3  30  부산  30대  학생
# 사람 1   1   2  서울  20대  학생

# %%
df = df.drop(['나이대', '직업'], axis = 1)

# %%
df
# Out:
#       순서  나이  도시
# 홍길동    1   2  서울
# 사람2    2  25  대전
# 사람 3   3  30  부산
# 사람 1   1   2  서울
